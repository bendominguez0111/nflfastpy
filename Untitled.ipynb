# %%
import nflfastpy
from nflfastpy.utils import convert_to_gsis_id
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
import requests

pd.set_option('display.max_columns', None)

# %%
df = nflfastpy.load_pbp_data(year=2020)

roster_df = nflfastpy.load_roster_data()

team_logo_df = nflfastpy.load_team_logo_data()

# %%
roster_df = roster_df.loc[roster_df['team.season'] == 2019]

air_yards_df = df.loc[df['pass_attempt'] == 1, ['receiver_player_id', 'posteam', 'air_yards']]

air_yards_df = air_yards_df.loc[air_yards_df['receiver_player_id'].notnull()]

air_yards_df['gsis_id'] = air_yards_df['receiver_player_id'].apply(convert_to_gsis_id)

# %%
#grabbing the top 5 air yards
top_5_air_yards = air_yards_df.groupby('gsis_id')['air_yards'].sum().sort_values(ascending=False)[:10].index.unique()

air_yards_df = air_yards_df.loc[air_yards_df['gsis_id'].isin(top_5_air_yards)]

# %%
fig, axes = plt.subplots(5, 2, figsize=(10, 20))

for i, row in enumerate(axes):
    
    ax1, ax2 = row[0], row[1]
    
    player_gsis_id = top_10_air_yards[i]
    
    player_df = air_yards_df.loc[air_yards_df['gsis_id'] == player_gsis_id]
    
    player_roster_data = roster_df.loc[roster_df['teamPlayers.gsisId'] == player_gsis_id]
    team_logo_data = team_logo_df.loc[team_logo_df['team_abbr'] == player_df['posteam'].values[0]]
    player_headshot = player_roster_data['teamPlayers.headshot_url'].values[0]
    team_color_1 = team_logo_data['team_color'].values[0]
    team_color_2 = team_logo_data['team_color2'].values[0]
    
    a = plt.imread(player_headshot)
    ax1.imshow(a)
    ax1.axis('off')

    sns.kdeplot(player_df['air_yards'], color=team_color_2, ax=ax2)

    x = ax2.get_lines()[0].get_xydata()[:, 0]
    y = ax2.get_lines()[0].get_xydata()[:, 1]
    ax2.set_xticks(range(-10, 60, 10))

    ax2.fill_between(x, y, color=team_color_1, alpha=0.5);

# %%
roster_df
# Out:
#        team.season teamPlayers.displayName teamPlayers.firstName  \
# 53064         2019        Keishawn Bierria              Keishawn
# 53065         2019        Clinton McDonald               Clinton
# 53066         2019            Jamey Mosley                 Jamey
# 53067         2019              Mason Cole                 Mason
# 53068         2019             J.R. Sweezy                  J.R.
# ...            ...                     ...                   ...
# 56170         2019             Donald Penn                Donald
# 56171         2019            Derrick Gore               Derrick
# 56172         2019          Pete Robertson                  Pete
# 56173         2019             Daron Payne                 Daron
# 56174         2019             Case Keenum                  Case
#
#       teamPlayers.middleName teamPlayers.lastName teamPlayers.suffix  \
# 53064                 Jaylyn              Bierria                NaN
# 53065                  Myles             McDonald                NaN
# 53066                    NaN               Mosley                NaN
# 53067                 Connor                 Cole                NaN
# 53068                   Ross               Sweezy                NaN
# ...                      ...                  ...                ...
# 56170                   Ward                 Penn                NaN
# 56171                    NaN                 Gore                NaN
# 56172          Jovan O'Keith            Robertson                NaN
# 56173                Cordell                Payne                NaN
# 56174                 Austin               Keenum                NaN
#
#       teamPlayers.status teamPlayers.positionGroup teamPlayers.position  \
# 53064                ACT                        LB                   LB
# 53065                RES                        DL                   DT
# 53066                DEV                        LB                   LB
# 53067                ACT                        OL                   OG
# 53068                ACT                        OL                   OG
# ...                  ...                       ...                  ...
# 56170                ACT                        OL                   OT
# 56171                DEV                        RB                   RB
# 56172                DEV                        LB                   LB
# 56173                ACT                        DL                   NT
# 56174                ACT                        QB                   QB
#
#        teamPlayers.nflId teamPlayers.esbId teamPlayers.gsisId  \
# 53064            2560976         BIE716450         00-0034422
# 53065              89758         MCD242013         00-0026964
# 53066            2563187         MOS391551         00-0035506
# 53067            2561025         COL151246         00-0034785
# 53068            2533342         SWE678847         00-0029146
# ...                  ...               ...                ...
# 56170            2506706         PEN244635         00-0023894
# 56171            2563347         GOR411061                NaN
# 56172            2556770         ROB359521         00-0032851
# 56173            2560834         PAY281222         00-0034333
# 56174            2532888         KEE690598         00-0028986
#
#       teamPlayers.birthDate teamPlayers.homeTown  teamPlayers.collegeId  \
# 53064            07/26/1995      Los Angeles, CA                   4854
# 53065            01/06/1987     Jacksonville, AR                   1459
# 53066            03/28/1996                  NaN                   1830
# 53067            03/28/1996          Batavia, IL                   1839
# 53068            04/08/1989      Mooresville, NC                   5496
# ...                     ...                  ...                    ...
# 56170            04/27/1983      Los Angeles, CA                   4857
# 56171                   NaN                  NaN                   6482
# 56172            12/02/1992         Longview, TX                   6827
# 56173            05/27/1997       Birmingham, AL                   1830
# 56174            02/17/1988        Brownwood, TX                   6870
#
#       teamPlayers.collegeName  teamPlayers.jerseyNumber teamPlayers.height  \
# 53064              Washington                      44.0                6-1
# 53065                 Memphis                      93.0                6-2
# 53066                 Alabama                       NaN                6-5
# 53067                Michigan                      52.0                6-5
# 53068    North Carolina State                      64.0                6-5
# ...                       ...                       ...                ...
# 56170              Utah State                      72.0                6-4
# 56171        Louisiana-Monroe                       NaN               5-10
# 56172              Texas Tech                       NaN                6-2
# 56173                 Alabama                      94.0                6-3
# 56174                 Houston                       8.0                6-1
#
#        teamPlayers.weight  team.teamId team.abbr team.cityState  \
# 53064               223.0         3800       ARI        Arizona
# 53065               297.0         3800       ARI        Arizona
# 53066               248.0         3800       ARI        Arizona
# 53067               307.0         3800       ARI        Arizona
# 53068               310.0         3800       ARI        Arizona
# ...                   ...          ...       ...            ...
# 56170               315.0         5110       WAS     Washington
# 56171               212.0         5110       WAS     Washington
# 56172               243.0         5110       WAS     Washington
# 56173               320.0         5110       WAS     Washington
# 56174               215.0         5110       WAS     Washington
#
#              team.fullName  team.nick team.conferenceAbbr team.divisionAbbr  \
# 53064    Arizona Cardinals  Cardinals                 NFC               NCW
# 53065    Arizona Cardinals  Cardinals                 NFC               NCW
# 53066    Arizona Cardinals  Cardinals                 NFC               NCW
# 53067    Arizona Cardinals  Cardinals                 NFC               NCW
# 53068    Arizona Cardinals  Cardinals                 NFC               NCW
# ...                    ...        ...                 ...               ...
# 56170  Washington Redskins   Redskins                 NFC               NCE
# 56171  Washington Redskins   Redskins                 NFC               NCE
# 56172  Washington Redskins   Redskins                 NFC               NCE
# 56173  Washington Redskins   Redskins                 NFC               NCE
# 56174  Washington Redskins   Redskins                 NFC               NCE
#
#                                 teamPlayers.headshot_url  \
# 53064  http://static.nfl.com/static/content/public/st...
# 53065  http://static.nfl.com/static/content/public/st...
# 53066  http://static.nfl.com/static/content/public/st...
# 53067  http://static.nfl.com/static/content/public/st...
# 53068  http://static.nfl.com/static/content/public/st...
# ...                                                  ...
# 56170  http://static.nfl.com/static/content/public/st...
# 56171  http://static.nfl.com/static/content/public/st...
# 56172  http://static.nfl.com/static/content/public/st...
# 56173  http://static.nfl.com/static/content/public/st...
# 56174  http://static.nfl.com/static/content/public/st...
#
#                                  teamPlayers.profile_url
# 53064  http://www.nfl.com/player/keishawnbierria/2560...
# 53065  http://www.nfl.com/player/clintonmcdonald/8975...
# 53066  http://www.nfl.com/player/jameymosley/2563187/...
# 53067  http://www.nfl.com/player/masoncole/2561025/pr...
# 53068  http://www.nfl.com/player/j.r.sweezy/2533342/p...
# ...                                                  ...
# 56170  http://www.nfl.com/player/donaldpenn/2506706/p...
# 56171  http://www.nfl.com/player/derrickgore/2563347/...
# 56172  http://www.nfl.com/player/peterobertson/255677...
# 56173  http://www.nfl.com/player/daronpayne/2560834/p...
# 56174  http://www.nfl.com/player/casekeenum/2532888/p...
#
# [3111 rows x 28 columns]

# %%
for ax1, ax2 in axes:
    print(ax1)
# Out:
# AxesSubplot(0.125,0.749828;0.352273x0.130172)
# AxesSubplot(0.125,0.593621;0.352273x0.130172)
# AxesSubplot(0.125,0.437414;0.352273x0.130172)
# AxesSubplot(0.125,0.281207;0.352273x0.130172)
# AxesSubplot(0.125,0.125;0.352273x0.130172)
